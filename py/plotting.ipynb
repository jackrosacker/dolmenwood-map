# %%
from localtileserver import get_leaflet_tile_layer
from localtileserver import TileClient
import ipyleaflet
from ipyleaflet import projections

# %%
# url = 'https://github.com/jackrosacker/dolmenwood-character-generator/raw/main/data/dolmenwood_map_COG.tif'

# # First, create a tile server from the URL raster file
# client = TileClient(url)

# # Create ipyleaflet tile layer from that server
# layer = get_leaflet_tile_layer(client)

# coords = ((y, x), (y, x))
bounds = ((100,-100), (-65,150))
center = (17.5, 25)

m = ipyleaflet.Map(
    #center=client.center(),
    center = center,
    zoom=1,#client.default_zoom,
    crs=projections.Simple,
)

image = ipyleaflet.ImageOverlay(
    url="raw/Dolmenwood_Blank_Hex_Map.jpg",
    bounds=bounds,
)
#4961 × 3508

# m.add(layer)
marker = ipyleaflet.Marker(location=center, draggable=False)
marker_2 = ipyleaflet.Marker(location=bounds[1])
m.add(image)
m.add(marker)
m
# Out:
# Map(center=[17.5, 25], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_t…

# %%
m.basemap
# Out:
# {'url': 'https://tile.openstreetmap.org/{z}/{x}/{y}.png',
#  'max_zoom': 19,
#  'html_attribution': '&copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors',
#  'attribution': '(C) OpenStreetMap contributors',
#  'name': 'OpenStreetMap.Mapnik'}
